# %% [markdown]
# # Sales Revenue Analysis - Jupyter Notebook
#
# This notebook presents an analysis of a retail sales dataset using Python (Pandas, Matplotlib, Seaborn).
# The objective is to calculate key KPIs, explore sales trends, and generate insights useful for decision-making.
#
# **Dataset:** superstore_sales.csv
# **Rows:** 8,772
# **Columns:** 10

# %% [markdown]
# ## Step 1: Import Libraries & Load Dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset
df = pd.read_csv("superstore_sales.csv")
df['Order Date'] = pd.to_datetime(df['Order Date'])

df.head()
# Out:
#     Order ID Order Date Region    Category Sub-Category  Quantity  Unit Price  \
# 0  ORD-10000 2023-01-01  North   Furniture    Bookcases         2      368.68
# 1  ORD-10001 2023-01-01  South   Furniture       Chairs         5       86.44
# 2  ORD-10002 2023-01-01  North  Technology     Machines         1      304.55
# 3  ORD-10003 2023-01-01  North   Furniture       Tables         2      485.26
# 4  ORD-10004 2023-01-01  North  Technology  Accessories         5       99.09
#
#    Discount     Sales      Profit
# 0      0.00  737.3600   96.744381
# 1      0.00  432.2000  118.092266
# 2      0.05  289.3225   30.123361
# 3      0.10  873.4680  124.441084
# 4      0.00  495.4500   79.692364

# %% [markdown]
# ## Step 2: Key KPIs

# %%
total_sales = df['Sales'].sum()
total_profit = df['Profit'].sum()
total_orders = df['Order ID'].nunique()
avg_order_value = total_sales / total_orders

print("Total Sales: ₹", round(total_sales,2))
print("Total Profit: ₹", round(total_profit,2))
print("Total Orders:", total_orders)
print("Average Order Value: ₹", round(avg_order_value,2))
# Out:
# Total Sales: ₹ 6409042.03
# Total Profit: ₹ 1287512.22
# Total Orders: 8772
# Average Order Value: ₹ 730.62

# %% [markdown]
# ## Step 3: Monthly Sales Trend

# %%
monthly_sales = df.groupby(df['Order Date'].dt.to_period('M'))['Sales'].sum().reset_index()
monthly_sales['Order Date'] = monthly_sales['Order Date'].astype(str)

plt.figure(figsize=(10,5))
plt.plot(monthly_sales['Order Date'], monthly_sales['Sales'], marker='o')
plt.xticks(rotation=45)
plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Sales")
plt.show()

# %% [markdown]
# ## Step 4: Sales by Region

# %%
region_sales = df.groupby('Region')['Sales'].sum().reset_index()

plt.figure(figsize=(6,4))
sns.barplot(x='Region', y='Sales', data=region_sales)
plt.title("Sales by Region")
plt.ylabel("Sales")
plt.show()

# %% [markdown]
# ## Step 5: Sales by Category

# %%
category_sales = df.groupby('Category')['Sales'].sum().reset_index()

plt.figure(figsize=(6,4))
sns.barplot(x='Category', y='Sales', data=category_sales)
plt.title("Sales by Category")
plt.ylabel("Sales")
plt.show()

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - **Total Sales:** ₹ 6,409,042.03
# - **Total Profit:** ₹ 1,287,512.22
# - **Orders:** 8772
# - **Average Order Value:** ₹ 730.62
#
# **Insights:**
# - Sales have shown a clear upward trend over the months.
# - The **North region** generated the highest sales compared to others.
# - Among categories, **Technology products** drove significant revenue, while **Furniture** lagged behind.
#
# This project demonstrates how Excel dashboards can be complemented with **Python-based analysis in Jupyter Notebook** for deeper insights.
